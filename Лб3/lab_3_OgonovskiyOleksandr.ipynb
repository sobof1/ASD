# %% [markdown]
# # Лабораторна робота №3. Аналіз складності алгоритмів. Алгоритми сортування
#
# Виконав - Огоновський Олександр

# %% [markdown]
# **Мета**:  засвоїти аналіз складності алгоритмів як технологію на прикладі
# алгоритмів сортування методами включення та обміну.

# %% [markdown]
# ## 1 . Виконати теоретичні розрахунки асимптотичної складності алгоритмів сорутвання методами вставки та бульбашки.

# %% [markdown]
# Сортування вставками:
# - У гіршому випадку (наприклад, масив відсортований у зворотному порядку) виконується O(n²) операцій.
# - У кращому випадку (якщо масив вже відсортовано) працює за O(n).
#
# Сортування бульбашкою:
# - У найгіршому випадку виконує O(n²) операцій.
# - У кращому випадку (якщо масив вже відсортовано) виконує O(n).
#
# Метод сортування вставками працює швидше бульбашкового сортування в більшості випадків, але обидва алгоритми неефективні для великих даних.

# %% [markdown]
# ## 2 . Реалізувати на Python алгоритм сортування методом бульбашки.

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# %% [markdown]
# ## 3 . Дослідити реальний час виконання обох алгоритмів на Python і побудувати графіки залежностей , згенерувавши відповідні цілочисельні масиви.

# %%
import time
import random
import matplotlib.pyplot as plt

# Сортування вставками
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >=0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# Сортування бульбашкою
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Функція для вимірювання часу
def measure_time(sort_func, arr):
    start = time.perf_counter()
    sort_func(arr.copy())  # копіюємо масив, щоб не змінювати оригінал
    end = time.perf_counter()
    return end - start

# Масиви різної довжини
sizes = [5, 10, 50, 100, 500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 50000, 100000]
times_insertion = []
times_bubble = []

for size in sizes:
    arr = [random.randint(0, 10000) for _ in range(size)]
    times_insertion.append(measure_time(insertion_sort, arr))
    times_bubble.append(measure_time(bubble_sort, arr))

# Побудова графіків
plt.plot(sizes, times_insertion, label='Insertion Sort', marker='o')
plt.plot(sizes, times_bubble, label='Bubble Sort', marker='s')
plt.xlabel('Розмір масиву')
plt.ylabel('Час виконання (секунди)')
plt.title('Порівняння часу сортування: вставки vs бульбашка')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4 . Контрольні питання

# %% [markdown]
# 1. **Що таке О-нотація та чим вона відрізняється від Ω-нотації**
#     О-нотація це верхня межа асимптотичної складності алгоритму а Ω нотація це нижня межа асимптотичної складності алгоритму
# 2. **Яку часову складність має алгоритм сортування методом вставляння за найсприятливіших умов, коли масив відсортовано? Відповідь обгрунтувати**.
#     складність буде O(n) , бо ми вставляємо відразу в початок масиву , нам не потрібно проходити через кожен елемент поки ми не знайдемо правльне положення для елемента , це означає що цикл вставки виконується лише один раз.
# 3. **Надати визначення ефективного алогоритму**
#     Ефективним алгоритмом є той , що за найменший час може опрацювати найбільшу кількість елементів.
# 4. **Пояснити поняття головного параметра (розміру) задачі.**
#     Цей параметр характеризує кількість вхідних даних і використовується для аналізу складності алгоритму.
# 5. **Функція часової складності має вигляд:$F(n) = n^3+7n^2-14n$. Як записати аисмптотичну складність в нотації O(n).**
#     $O(n^3)$.Тому що $n^3$ є домінуючим членом цієї функції (константи відкидаємо та менші члени також).
